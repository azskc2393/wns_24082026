# %% [markdown]
# ## DATABRICKS TRAINING SESSIONS
# <br>**DATE: 2026-08-27**
# <br>**TOPIC: NOTEBOOK UTILITIES**

# %%
dbutils.notebook.run(path = '/Workspace/Users/surajchhetri2393@gmail.com/wns_24082026/02. Databricks Intelligence Platform/ChildNotebook',timeout_seconds=300, arguments={"exp_level": "Senior"})
